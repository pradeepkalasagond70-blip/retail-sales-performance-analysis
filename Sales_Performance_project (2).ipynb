# %%
import pandas as pd
import matplotlib as plyt
import seaborn as sns

# %%
df = pd.read_excel("/content/Sample - Superstore.xlsx")

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 1       2  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 2       3  CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045
# 3       4  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
# 4       5  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.isna().sum()
# Out:
# Row ID             0
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country/Region     0
# City               0
# State              0
# Postal Code       11
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  9983.000000                           9983
# mean   4993.886207  2020-04-29 21:46:43.045176832
# min       1.000000            2018-01-03 00:00:00
# 25%    2497.500000            2019-05-22 00:00:00
# 50%    4993.000000            2020-06-26 00:00:00
# 75%    7489.500000            2021-05-14 00:00:00
# max    9994.000000            2021-12-30 00:00:00
# std    2883.738990                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9983   9983.000000   9983.000000  9983.000000
# mean   2020-05-03 20:46:42.684563712  55245.233297    229.216818     3.788741
# min              2018-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2019-05-26 00:00:00  23223.000000     17.280000     2.000000
# 50%              2020-06-29 00:00:00  57103.000000     54.384000     3.000000
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 1       2  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 2       3  CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045
# 3       4  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
# 4       5  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.groupby("Category")[["Sales", "Profit"]].sum()
# Out:
#                        Sales       Profit
# Category
# Furniture        736879.6953   17259.3458
# Office Supplies  716837.5220  121885.0358
# Technology       834554.2730  145007.6618

# %%
df.groupby(["Category","Region"])[["Sales", "Profit"]].sum().sort_values(by="Profit", ascending=False).sort_values(by="Sales", ascending=False)
# Out:
#                                Sales      Profit
# Category        Region
# Technology      East     263374.2210  47014.7488
# Furniture       West     252612.7435  11504.9503
# Technology      West     251991.8320  44303.6496
# Office Supplies West     220853.2490  52609.8490
#                 East     203306.5450  40408.8141
# Furniture       East     203171.1040   1854.2388
# Technology      Central  170416.3120  33697.4320
# Office Supplies Central  167026.4150   8879.9799
# Furniture       Central  163797.1638  -2871.0494
# Technology      South    148771.9080  19991.8314
# Office Supplies South    125651.3130  19986.3928
# Furniture       South    117298.6840   6771.2061

# %%
df.groupby(["Category","Region"])[["Sales", "Profit"]].sum().sort_values(by="Profit", ascending=False)
# Out:
#                                Sales      Profit
# Category        Region
# Office Supplies West     220853.2490  52609.8490
# Technology      East     263374.2210  47014.7488
#                 West     251991.8320  44303.6496
# Office Supplies East     203306.5450  40408.8141
# Technology      Central  170416.3120  33697.4320
#                 South    148771.9080  19991.8314
# Office Supplies South    125651.3130  19986.3928
# Furniture       West     252612.7435  11504.9503
# Office Supplies Central  167026.4150   8879.9799
# Furniture       South    117298.6840   6771.2061
#                 East     203171.1040   1854.2388
#                 Central  163797.1638  -2871.0494

# %%
df.groupby(["Category","Region"]) ["Discount"].mean().sort_values(ascending=False)
# Out:
# Category         Region
# Furniture        Central    0.297380
# Office Supplies  Central    0.252743
#                  South      0.167437
# Furniture        East       0.154591
# Technology       East       0.144173
# Office Supplies  East       0.143435
# Technology       West       0.133890
#                  Central    0.133095
# Furniture        West       0.131400
#                  South      0.121536
# Technology       South      0.107850
# Office Supplies  West       0.093358
# Name: Discount, dtype: float64

# %%
df.groupby(["Category","Region"])[["Sales", "Profit","Quantity"]].sum().sort_values(by=["Profit","Sales","Quantity"] ,ascending=[False,False,False])
# Out:
#                                Sales      Profit  Quantity
# Category        Region
# Office Supplies West     220853.2490  52609.8490      7235
# Technology      East     263374.2210  47014.7488      1928
#                 West     251991.8320  44303.6496      2335
# Office Supplies East     203306.5450  40408.8141      6434
# Technology      Central  170416.3120  33697.4320      1544
#                 South    148771.9080  19991.8314      1118
# Office Supplies South    125651.3130  19986.3928      3800
# Furniture       West     252612.7435  11504.9503      2696
# Office Supplies Central  167026.4150   8879.9799      5409
# Furniture       South    117298.6840   6771.2061      1291
#                 East     203171.1040   1854.2388      2206
#                 Central  163797.1638  -2871.0494      1827

# %%
df.groupby("Product Name")["Profit"].sum()
# Out:
# Product Name
# "While you Were Out" Message Book, One Form per Page                                                    10.3880
# #10 Gummed Flap White Envelopes, 100/Box                                                                16.7678
# #10 Self-Seal White Envelopes                                                                           52.1230
# #10 White Business Envelopes,4 1/8 x 9 1/2                                                             223.1408
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                                                                115.2806
#                                                                                                          ...
# iKross Bluetooth Portable Keyboard + Cell Phone Stand Holder + Brush for Apple iPhone 5S 5C 5, 4S 4    115.6440
# iOttie HLCRIO102 Car Mount                                                                             -11.9940
# ...

# %%
df[(df["Category"] == "Furniture") &(df["Region"] == "Central")]
df.groupby("Product Name")["Profit"].sum()
# Out:
# Product Name
# "While you Were Out" Message Book, One Form per Page                                                    10.3880
# #10 Gummed Flap White Envelopes, 100/Box                                                                16.7678
# #10 Self-Seal White Envelopes                                                                           52.1230
# #10 White Business Envelopes,4 1/8 x 9 1/2                                                             223.1408
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                                                                115.2806
#                                                                                                          ...
# iKross Bluetooth Portable Keyboard + Cell Phone Stand Holder + Brush for Apple iPhone 5S 5C 5, 4S 4    115.6440
# iOttie HLCRIO102 Car Mount                                                                             -11.9940
# ...

# %%
df.groupby("Product Name")["Profit"].sum()
# Out:
# Product Name
# "While you Were Out" Message Book, One Form per Page                                                    10.3880
# #10 Gummed Flap White Envelopes, 100/Box                                                                16.7678
# #10 Self-Seal White Envelopes                                                                           52.1230
# #10 White Business Envelopes,4 1/8 x 9 1/2                                                             223.1408
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                                                                115.2806
#                                                                                                          ...
# iKross Bluetooth Portable Keyboard + Cell Phone Stand Holder + Brush for Apple iPhone 5S 5C 5, 4S 4    115.6440
# iOttie HLCRIO102 Car Mount                                                                             -11.9940
# ...

# %%
furniture_central = df[
    (df["Category"] == "Furniture") &
    (df["Region"] == "Central")
]

# %%
furniture_central.groupby("Product Name")[["Sales","Profit","Discount"]].sum().sort_values(by="Profit",ascending=True)
# Out:
#                                                         Sales    Profit  \
# Product Name
# Tenex Chairmat w/ Average Lip, 45" x 53"             544.8960 -681.1200
# Bevis Oval Conference Table, Walnut                 1565.8800 -600.2540
# BoxOffice By Design Rectangular and Half-Moon M...   765.6250 -566.5625
# O'Sullivan Plantations 2-Door Library in Landve...  2323.3288 -546.6656
# Bretford “Just In Time” Height-Adjustable Multi...   626.1000 -538.4460
# ...                                                       ...       ...
# Hon GuestStacker Chair                              2266.7000  589.3420
# Global Executive Mid-Back Manager's Chair           2327.8400  605.2384
# Office Star - Professional Matrix Back Chair wi...  2807.8400  673.8816
# Hon Deluxe Fabric Upholstered Stacking Chairs, ...  2439.8000  731.9400
# Hon Pagoda Stacking Chairs                          2567.8400  770.3520
#
#                                                     Discount
# Product Name
# ...

# %%
import numpy as np
furniture_central.groupby("Product Name")[["Sales", "Profit", "Discount"]].agg({
    "Sales": "sum",
    "Profit": "sum",
    "Discount":"mean"
}).sort_values(by="Profit" , ascending = True)
# Out:
#                                                         Sales    Profit  \
# Product Name
# Tenex Chairmat w/ Average Lip, 45" x 53"             544.8960 -681.1200
# Bevis Oval Conference Table, Walnut                 1565.8800 -600.2540
# BoxOffice By Design Rectangular and Half-Moon M...   765.6250 -566.5625
# O'Sullivan Plantations 2-Door Library in Landve...  2323.3288 -546.6656
# Bretford “Just In Time” Height-Adjustable Multi...   626.1000 -538.4460
# ...                                                       ...       ...
# Hon GuestStacker Chair                              2266.7000  589.3420
# Global Executive Mid-Back Manager's Chair           2327.8400  605.2384
# Office Star - Professional Matrix Back Chair wi...  2807.8400  673.8816
# Hon Deluxe Fabric Upholstered Stacking Chairs, ...  2439.8000  731.9400
# Hon Pagoda Stacking Chairs                          2567.8400  770.3520
#
#                                                     Discount
# Product Name
# ...

# %%
furniture_central["Profit_Margin"] = (
    furniture_central["Profit"] / furniture_central["Sales"]
)
# Out:
# /tmp/ipykernel_946/215221743.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   furniture_central["Profit_Margin"] = (

# %%
furniture_central.groupby("Product Name")["Profit_Margin"].mean().sort_values(ascending=True)
# Out:
# Product Name
# 36X48 HARDFLOOR CHAIRMAT                                        -1.325
# Tenex Chairmats For Use with Hard Floors                        -1.300
# Tenex Antistatic Computer Chair Mats                            -1.250
# Tenex Chairmat w/ Average Lip, 45" x 53"                        -1.250
# Eldon Cleatmat Plus Chair Mats for High Pile Carpets            -1.225
#                                                                  ...
# Eldon Regeneration Recycled Desk Accessories, Black              0.390
# Advantus Employee of the Month Certificate Frame, 11 x 13-1/2    0.410
# C-Line Magnetic Cubicle Keepers, Clear Polypropylene             0.420
# Master Giant Foot Doorstop, Safety Yellow                        0.430
# Electrix 20W Halogen Replacement Bulb for Zoom-In Desk Lamp      0.480
# Name: Profit_Margin, Length: 270, dtype: float64

# %%
product_summary = furniture_central.groupby("Product Name")[["Sales", "Profit", "Discount","Profit_Margin"]].agg({
    "Sales": "sum",
    "Profit": "sum",
    "Discount":"mean",
    "Profit_Margin":"mean"
}).sort_values(by="Profit" , ascending = True)

# %%
df["Discount"].median()
# Out:
# 0.2

# %%
product_summary[product_summary["Discount"] > 0.20].sort_values(by="Discount", ascending=False)
# Out:
#                                                         Sales    Profit  \
# Product Name
# Tenex Chairmat w/ Average Lip, 45" x 53"             544.8960 -681.1200
# Luxo Professional Fluorescent Magnifier Lamp wi...   419.6800 -356.7280
# Deflect-o RollaMat Studded, Beveled Mat for Med...   405.8120 -426.1026
# Tenex Antistatic Computer Chair Mats                 341.9600 -427.4500
# Eldon Advantage Foldable Chair Mats for Low Pil...   108.4000 -105.6900
# ...                                                       ...       ...
# Novimex Swivel Fabric Task Chair                    1570.1920 -311.0188
# Global Value Mid-Back Manager's Chair, Gray          487.1200  -15.2225
# Bevis Round Conference Table Top & Single Colum...  1946.3220   96.5844
# Global Deluxe High-Back Manager's Chair             3803.5340  554.8012
# Atlantic Metals Mobile 3-Shelf Bookcases, Custo...  3011.7092  307.9564
#
#                                                     Discount  Profit_Margin
# ...

# %%
import matplotlib.pyplot as plt
product_summary[["Discount", "Profit_Margin"]].corr()
# Out:
#                Discount  Profit_Margin
# Discount       1.000000      -0.888271
# Profit_Margin -0.888271       1.000000

# %%
plt.figure(figsize=(8,6))
plt.scatter(x = product_summary["Discount"], y = product_summary["Profit_Margin"])
plt.xlabel("Discount")
plt.ylabel("Profit_Margin")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
X = product_summary[["Discount"]]
y = product_summary["Profit_Margin"]
print(X.shape)
print(y.shape)
# Out:
# (270, 1)
# (270,)

# %%
model.fit(X, y)
model.coef_
# Out:
# array([-1.59614541])

# %%
y_pred = model.predict(X)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred)
plt.xlabel("Discount")
plt.ylabel("Profit_Margin")
plt.show()

# %%
model.intercept_
model.score(X, y)
# Out:
# 0.789025364261767

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y, y_pred)
mae
# Out:
# 0.1341843039892867

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (216, 1)
# (54, 1)
# (216,)
# (54,)

# %%
model_test = LinearRegression()
model_test.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_test_pred = model_test.predict(X_test)
y_test_pred = model_test.predict(X_test)

# %%
r2_test = model_test.score(X_test, y_test)
r2_test
# Out:
# 0.8075241893703935

# %%
mae_test = mean_absolute_error(y_test, y_test_pred)
mae_test
# Out:
# 0.14245225740168857

# %%
product_summary.sort_values(
    by="Profit_Margin",
    ascending=True
).head(10)
# Out:
#                                                       Sales    Profit  \
# Product Name
# 36X48 HARDFLOOR CHAIRMAT                             41.960  -55.5970
# Tenex Chairmats For Use with Hard Floors            103.936 -135.1168
# Tenex Antistatic Computer Chair Mats                341.960 -427.4500
# Tenex Chairmat w/ Average Lip, 45" x 53"            544.896 -681.1200
# Eldon Cleatmat Plus Chair Mats for High Pile Ca...  159.040 -194.8240
# Eldon "L" Workstation Diamond Chairmat              151.960 -182.3520
# Tenex Traditional Chairmats for Hard Floors, Av...   51.560  -61.8720
# Eldon Cleatmat Chair Mats for Medium Pile Carpets    66.600  -78.2550
# Tenex "The Solids" Textured Chair Mats              223.872 -240.6624
# Tensor Brushed Steel Torchiere Floor Lamp            13.592  -14.2716
#
#                                                     Discount  Profit_Margin
# Product Name
# 36X48 HARDFLOOR CHAIRMAT                                 0.6         -1.325
# ...

# %%
product_summary[product_summary["Profit"] < 0]["Profit"].sum()
# Out:
# np.float64(-16393.0168)

# %%
product_summary[
    (product_summary["Discount"] > 0.20) &
    (product_summary["Profit"] < 0)
]["Profit"].sum()
# Out:
# np.float64(-15591.967900000001)

# %%
high_discount_loss = product_summary[
    (product_summary["Discount"] > 0.20) &
    (product_summary["Profit"] < 0)
]

len(high_discount_loss)
# Out:
# 158

# %%
len(product_summary)
# Out:
# 270

# %%
high_discount_loss.sort_values(
    by="Profit",
    ascending=True
).head(10)
# Out:
#                                                         Sales    Profit  \
# Product Name
# Tenex Chairmat w/ Average Lip, 45" x 53"             544.8960 -681.1200
# Bevis Oval Conference Table, Walnut                 1565.8800 -600.2540
# BoxOffice By Design Rectangular and Half-Moon M...   765.6250 -566.5625
# O'Sullivan Plantations 2-Door Library in Landve...  2323.3288 -546.6656
# Bretford “Just In Time” Height-Adjustable Multi...   626.1000 -538.4460
# O'Sullivan Living Dimensions 5-Shelf Bookcases      1652.9304 -534.7716
# Hon Rectangular Conference Tables                    796.4250 -525.6405
# Tenex Antistatic Computer Chair Mats                 341.9600 -427.4500
# Deflect-o RollaMat Studded, Beveled Mat for Med...   405.8120 -426.1026
# Luxo Professional Fluorescent Magnifier Lamp wi...   419.6800 -356.7280
#
#                                                     Discount  Profit_Margin
# Product Name
# ...

# %%
top_10_loss = high_discount_loss.sort_values(
    by="Profit",
    ascending=True
).head(10)

top_10_loss["Profit"].sum()
# Out:
# np.float64(-5203.7408000000005)

# %%
high_discount_loss["Profit"].sum()
# Out:
# np.float64(-15591.967900000001)

# %%
top_10_loss.reset_index().plot(
    x="Product Name",
    y="Profit",
    kind="barh",
    figsize=(10, 6)
)

plt.xlabel("Profit")
plt.ylabel("Product")
plt.title("Top 10 Loss-Making Products — Furniture, Central")
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.scatter(
    product_summary["Discount"],
    product_summary["Profit_Margin"]
)

plt.xlabel("Discount")
plt.ylabel("Profit Margin")
plt.title("Discount vs Profit Margin — Furniture, Central")

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.scatter(
    product_summary["Discount"],
    product_summary["Profit_Margin"]
)

plt.plot(
    product_summary["Discount"],
    model.predict(product_summary[["Discount"]])
)

plt.xlabel("Discount")
plt.ylabel("Profit Margin")
plt.title("Discount vs Profit Margin — Linear Regression")

plt.show()

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df["Profit_Margin"] = df["Profit"] / df["Sales"]

# %%
df[["Sales", "Profit", "Discount", "Profit_Margin"]].head()
# Out:
#       Sales    Profit  Discount  Profit_Margin
# 0  261.9600   41.9136      0.00         0.1600
# 1  731.9400  219.5820      0.00         0.3000
# 2   14.6200    6.8714      0.00         0.4700
# 3  957.5775 -383.0310      0.45        -0.4000
# 4   22.3680    2.5164      0.20         0.1125

# %%
df.to_excel("furniture_analysis_final.xlsx", index=False)

# %%
from google.colab import files

files.download("furniture_analysis_final.xlsx")
